# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel(r'E:\PHD\python\p 1\bupa.data1.xlsx');
df.head()
# Out:
#    mean corpuscular volume   alkaline phosphotase  alanine aminotransferase   \
# 0                        85                    92                         45
# 1                        85                    64                         59
# 2                        86                    54                         33
# 3                        91                    78                         34
# 4                        87                    70                         12
#
#    aspartate aminotransferase  gamma-glutamyl transpeptidase  target  \
# 0                          27                             31     0.0
# 1                          32                             23     0.0
# 2                          16                             54     0.0
# 3                          24                             36     0.0
# 4                          28                             10     0.0
#
#    train/test
# 0           1
# 1           2
# 2           2
# 3           2
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345 entries, 0 to 344
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   mean corpuscular volume        345 non-null    int64
#  1   alkaline phosphotase           345 non-null    int64
#  2   alanine aminotransferase       345 non-null    int64
#  3   aspartate aminotransferase     345 non-null    int64
#  4   gamma-glutamyl transpeptidase  345 non-null    int64
#  5   target                         345 non-null    float64
#  6   train/test                     345 non-null    int64
# dtypes: float64(1), int64(6)
# memory usage: 19.0 KB

# %%
df.describe()
# Out:
#        mean corpuscular volume   alkaline phosphotase  \
# count                345.000000            345.000000
# mean                  90.159420             69.869565
# std                    4.448096             18.347670
# min                   65.000000             23.000000
# 25%                   87.000000             57.000000
# 50%                   90.000000             67.000000
# 75%                   93.000000             80.000000
# max                  103.000000            138.000000
#
#        alanine aminotransferase   aspartate aminotransferase  \
# count                 345.000000                  345.000000
# mean                   30.405797                   24.643478
# std                    19.512309                   10.064494
# min                     4.000000                    5.000000
# 25%                    19.000000                   19.000000
# 50%                    26.000000                   23.000000
# ...

# %%
sns.pairplot(df)

# %%
y=df.target

# %%
x=df.values[:,[0,1]]

# %%
plt.scatter(x[:,0],x[:,1],c=y)

# %%
x1=df.values[:,[2,3]]

# %%
plt.scatter(x1[:,0],x1[:,1],c=y)

# %%
x2=df.values[:,[3,4]]

# %%
plt.scatter(x2[:,0],x2[:,1],c=y)

# %%
plt.boxplot(df)
plt.show()

# %%
df.corr()
# Out:
#                                mean corpuscular volume   alkaline phosphotase  \
# mean corpuscular volume                        1.000000              0.044103
# alkaline phosphotase                           0.044103              1.000000
# alanine aminotransferase                       0.147695              0.076208
# aspartate aminotransferase                     0.187765              0.146057
# gamma-glutamyl transpeptidase                  0.222314              0.133140
# target                                         0.312680              0.100796
# train/test                                    -0.091070             -0.098050
#
#                                alanine aminotransferase   \
# mean corpuscular volume                         0.147695
# alkaline phosphotase                            0.076208
# alanine aminotransferase                        1.000000
# aspartate aminotransferase                      0.739675
# ...
